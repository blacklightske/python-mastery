# %%
import pandas as pd

# %%
data = {
    "product": ["Milk", "Bread", "Sugar", "Juice", "Rice"],
    "price": [100, 60, 80, 150, 200],
    "quantity": [20, 30, 10, 5, 15]
}

df = pd.DataFrame( data )

df[["price","product"]]
# Out:
#    price product
# 0    100    Milk
# 1     60   Bread
# 2     80   Sugar
# 3    150   Juice
# 4    200    Rice
